# %% [markdown]
# # LightGBM Partial Dependence
# Compute and display PDPs for the top features using the saved LightGBM pipeline.

# %%
from pathlib import Path
import sys

# Ensure repo root is on the path
repo_root = Path.cwd().resolve()
while not (repo_root / 'src').is_dir() and repo_root.parent != repo_root:
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root / 'src'))

from package.pdp_plots import plot_lgbm_pdp, top_lgbm_features

# Get top features and plot PDPs with both models overlaid
top_features, importances = top_lgbm_features()
fig, plot_path, used_features = plot_lgbm_pdp()
fig
# Out:
# c:\Users\tilik\anaconda3\envs\d100_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\tilik\anaconda3\envs\d100_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\tilik\anaconda3\envs\d100_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\tilik\anaconda3\envs\d100_env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
import pandas as pd
from IPython.display import Image, display

# Show the top importances and the saved image
display(importances.head(10))
display(Image(filename=str(plot_path)))
print('Features used for PDP:', used_features)
# Out:
#                           feature  importance
# 0              numeric__over_time        1518
# 1                    numeric__smv        1365
# 2                   numeric__team        1302
# 3            numeric__day_numeric        1279
# 4              numeric__incentive        1104
# 5          numeric__no_of_workers        1006
# 6                numeric__quarter         888
# 7  numeric__targeted_productivity         862
# 8                    numeric__wip         766
# 9     numeric__no_of_style_change         101
# Features used for PDP: ['over_time', 'smv', 'team', 'day_numeric', 'incentive']
